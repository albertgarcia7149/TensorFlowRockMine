# %% [markdown]
# # TensorFlow Tutorial

# %% [markdown]
#  From Edureka TensorFlow Tutorials
#  https://www.edureka.co/ai-deep-learning-with-tensorflow

# %% [markdown]
# # Build Computational Graph

# %% [markdown]
# Notice if we print node1 and node2 without creating a session we get an abstract tensor as an output

# %%
import tensorflow as tf

node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)

print(node1,node2)
# Out:
# Tensor("Const_2:0", shape=(), dtype=float32) Tensor("Const_3:0", shape=(), dtype=float32)

# %% [markdown]
# # Now Lets Add The Session

# %% [markdown]
# 1. Now we create a session then print node1 and node2 from the session
# 2. After we are done with the session we must close it (it frees the memory we were using)
# 3. The output for this will be the actual float values we defined

# %%
import tensorflow as tf

node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)

sess= tf.Session()

print(sess.run([node1,node2]))

sess.close()
# Out:
# [3.0, 4.0]

# %% [markdown]
# # Lets Use A With Statement

# %% [markdown]
# 1. Using pythons with statement we can use the session for the following block of code
# 2. Once the block of code is done executing the with statement closes the session

# %%
import tensorflow as tf

node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)

sess= tf.Session()

with tf.Session() as sess:
    output = sess.run([node1,node2])
    print(output)
# Out:
# [3.0, 4.0]

# %% [markdown]
# # Lets Add Another Value

# %% [markdown]
# 1. We define a new variable c and set it to the value a*b
# 2. We make the session and it creates the variables and as you can see we get the expected result

# %%
import tensorflow as tf

#build graph
a = tf.constant(5.0)
b = tf.constant(6.0)

c = a * b

#launch the graph in a session
sess = tf.Session()

#Evaluate the tensor 'c'
print(sess.run(c))

#close session
sess.close()
# Out:
# 30.0

# %% [markdown]
# # TensorBoard

# %% [markdown]
# 1. If we want to visualize tensorflow we use tensorflow
# 2. Need to use \\ or / in the path variable (makes it a raw string literal)
# 3. This should generate a file that will be used to visualize our graph

# %%
import tensorflow as tf

#build graph
a = tf.constant(5.0)
b = tf.constant(6.0)

c = a * b

#launch the graph in a session
sess = tf.Session()

#Create the graph file (note file writers parameters are a 'path' and a 'session')
File_Writer = tf.summary.FileWriter('C:\\Users\\albg1\\OneDrive\\Documents\\Coding\\Python\\TensorFlowTutorial\\graph',sess.graph)

#Evaluate the tensor 'c'
print(sess.run(c))

#close session
sess.close()
# Out:
# 30.0

# %% [markdown]
# 4. We need to execute a command with this file in command line
# 5. Navigate to your working directory and then use the command 'tensorboard --logdir="TensorFlow"'
# (for me:
# cd C:\Users\albg1\OneDrive\Documents\Coding\Python
# tensorboard --logdir="TensorFlowTutorial"
# 6. It will give you a locally hosted webpage with a visual representation of your graph

# %% [markdown]
# # What You Can Do While In TensorBoard

# %% [markdown]
# You can select different nodes and information about that node will be displayed
# It explains the operations that are specified in your code (doesn't show the model output)

# %% [markdown]
# # Placeholders

# %% [markdown]
# 1. We have been using constants as our input up to this point.
# 2. What if we want the graph to accept external input?
# 3. We need to use placeholders (a placeholder is a promise to provide a value later)
# 4. Notice the result (1+2=3 and 3+4=7)

# %%
import tensorflow as tf

#define 2 placeholders
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)

adder_node = a + b

#make session
sess = tf.Session()

# note the values that will be fed to the placeholders are
# a 1,3
# b 2,4
print(sess.run(adder_node,{a:[1,3], b:[2,4]}))
# Out:
# [ 3.  7.]

# %% [markdown]
# # Variables And Simple Linear Model

# %% [markdown]
# 1. How Do I Modify The Graph So That The Same Input Can Give Back A Different Output?
# 2. To make the model trainable we need parameters that can change after every iteration this way the model can change to fit the actual output.
# 3. We need variables, variables allow us to add trainable parameters to a graph
# 4. Variables are in memory buffers containing tensors
# 5. Must be explicitly initialized
# 6. We make a loss function so we know how far from the actual values our calculations are
# 7. We need to initialize all the variables we created when we run the session

# %%
import tensorflow as tf

#model parameters
W = tf.Variable([.3],tf.float32)
b = tf.Variable([-.3],tf.float32)

#input placeholder
x = tf.placeholder(tf.float32)
#output placeholder
y = tf.placeholder(tf.float32)

linear_model = W * x + b

#loss function
squared_delta = tf.square(linear_model-y)
loss = tf.reduce_sum(squared_delta)

#initialize all the variables
init = tf.global_variables_initializer()

#make session
sess = tf.Session()

#run session with the global variable initializer
sess.run(init)

print(sess.run(loss, {x:[1,2,3,4], y:[0,-1,-2,-3]}))
# Out:
# 23.66

# %% [markdown]
# # What To Do With The Loss

# %% [markdown]
# 1. Above we got a loss value
# 2. The loss is calculated from our linear model W * x + b
# 3. Notice below that if we change the values .3 and -.3 to -1 and 1 the loss is 0
# 4. Why does this happen?
# 5. Lets look at the math
#     linear model: W * x + b (W=-1 and x=1)
#     input x values: [1,2,3,4]
#     expected y values: [0,-1,-2,-3]
#     1: (-1)(1) + 1 = 0
#     2: (-1)(2) + 1 = -1
#     3: (-1)(3) + 1 = -2
#     4: (-1)(4) + 1 = -3
#
#     The above values are exactly what we expected
#
# 6. If you update the values while running we can reduce our lost function

# %%
import tensorflow as tf

#model parameters
W = tf.Variable([-1.0],tf.float32)
b = tf.Variable([1.0],tf.float32)

#input placeholder
x = tf.placeholder(tf.float32)
#output placeholder
y = tf.placeholder(tf.float32)

linear_model = W * x + b

#loss function
squared_delta = tf.square(linear_model-y)
loss = tf.reduce_sum(squared_delta)

#initialize all the variables
init = tf.global_variables_initializer()

#make session
sess = tf.Session()

#run session with the global variable initializer
sess.run(init)

print(sess.run(loss, {x:[1,2,3,4], y:[0,-1,-2,-3]}))
# Out:
# 0.0

# %% [markdown]
# # Optimizer

# %% [markdown]
# 1. Optimizer modifies each variable according to the magnitude of the derivate of loss with respect to that variable.
# 2. Here we will be using the Gradient Descent Optimizer

# %%
import tensorflow as tf

#model parameters
W = tf.Variable([-1.0],tf.float32)
b = tf.Variable([1.0],tf.float32)

#input placeholder
x = tf.placeholder(tf.float32)
#output placeholder
y = tf.placeholder(tf.float32)

linear_model = W * x + b

#loss function
squared_delta = tf.square(linear_model-y)
loss = tf.reduce_sum(squared_delta)

#optimizer       0.01 is the learning rate
optimizer = tf.train.GradientDescentOptimizer(0.01)
train = optimizer.minimize(loss)

#initialize all the variables
init = tf.global_variables_initializer()

#make session
sess = tf.Session()

#run session with the global variable initializer
sess.run(init)

#run the session 1000 times
for i in range(1000):
    sess.run(train,{x:[1,2,3,4], y:[0,-1,-2,-3]})

#print W and b to see what they change to
print(sess.run([W,b]))
# Out:
# [array([-1.], dtype=float32), array([ 1.], dtype=float32)]

# %% [markdown]
# # How Do We Get The Data

# %% [markdown]
# 1. We must read the dataset
# 2. Define features and labels
# 3. Encode the dependent variable (preprocessing)
# 4. Divide dataset into two parts for testing
# 5. Once we have all of those we can run it through TensorFlow

# %% [markdown]
# Lets Code It
# 1. Make sure you have all the required packages
# 2. Read the data
# 3. Label Encode gives an integer value to each character in this case M=1 and R=0
# 4. One Hot Encode M=[1,0] R=[0,1] only one input active at a time

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#read the dataset
def read_dataset():
    df = pd.read_csv("C:\\Users\\albg1\\OneDrive\\Documents\\Coding\\Python\\TensorFlowTutorial\\sonar.csv",header=None)
    #print(len(df.columns))
    X = df[df.columns[0:60]].values
    y = df[df.columns[60]]
    
    #encode the dependent variable
    encoder = LabelEncoder()
    encoder.fit(y)
    y = encoder.transform(y)
    Y = one_hot_encode(y)
    print(X.shape)
    return(X,Y)

#define the encoder function
def one_hot_encode(labels):
    n_labels = len(labels)
    n_unique_labels = len(np.unique(labels))
    one_hot_encode = np.zeros((n_labels, n_unique_labels))
    one_hot_encode[np.arange(n_labels), labels]=1
    return one_hot_encode


#read the dataset
X,Y = read_dataset()

#shuffle the dataset to mix up the rows
X,Y = shuffle(X,Y,random_state=1)

#convert the dataset into train and test part
train_x, test_x, train_y, test_y = train_test_split(X,Y, test_size=0.20, random_state=415)

#inspect the shape of the training and testing
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)

#define the important parameters and variables to work with the tensors
learning_rate = 0.3 
training_epochs =1000 #total number of iterations done to minimize loss
cost_history = np.empty(shape=[1], dtype=float)
n_dim = X.shape[1]
print("n_dim",n_dim)
n_class = 2 # number of classes (M,R) so 2
model_path = "C:\\Users\\albg1\\OneDrive\\Documents\\Coding\\Python\\TensorFlowTutorial\\NMI"

#define the number of hidden layers and number of neurons for each layer
n_hidden_1 = 60
n_hidden_2 = 60
n_hidden_3 = 60
n_hidden_4 = 60

x = tf.placeholder(tf.float32, [None,n_dim])
W = tf.Variable(tf.zeros([n_dim,n_class]))
b = tf.Variable(tf.zeros([n_class]))
y_ = tf.placeholder(tf.float32, [None, n_class])

#define the model
def multilayer_perceptron(x,weights, biases):
    
    #hidden layer with sigmoid activation
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_1 = tf.nn.sigmoid(layer_1)
    
    #hidden layer with sigmoid activation
    layer_2 = tf.add(tf.matmul(layer_1,weights['h2']),biases['b2'])
    layer_2 = tf.nn.sigmoid(layer_2)
    
    #hidden layer with sigmoid activation
    layer_3 = tf.add(tf.matmul(layer_2,weights['h3']),biases['b3'])
    layer_3 = tf.nn.sigmoid(layer_3)
    
    #hidden layer with RELU activation
    layer_4 = tf.add(tf.matmul(layer_3,weights['h4']),biases['b4'])
    layer_4 = tf.nn.relu(layer_4)
    
    #output layer with linear activation
    out_layer = tf.matmul(layer_4, weights['out']) + biases['out']
    return out_layer

#define the weights and biases for each layer
weights = {
    'h1': tf.Variable(tf.truncated_normal([n_dim, n_hidden_1])),
    'h2': tf.Variable(tf.truncated_normal([n_hidden_1, n_hidden_2])),
    'h3': tf.Variable(tf.truncated_normal([n_hidden_2, n_hidden_3])),
    'h4': tf.Variable(tf.truncated_normal([n_hidden_3, n_hidden_4])),
    'out': tf.Variable(tf.truncated_normal([n_hidden_4, n_class]))
}
biases = {
    'b1': tf.Variable(tf.truncated_normal([n_hidden_1])),
    'b2': tf.Variable(tf.truncated_normal([n_hidden_2])),
    'b3': tf.Variable(tf.truncated_normal([n_hidden_3])),
    'b4': tf.Variable(tf.truncated_normal([n_hidden_4])),
    'out': tf.Variable(tf.truncated_normal([n_class]))
}

#initialize all the variables

init = tf.global_variables_initializer()

saver = tf.train.Saver()

#call your model defined
y = multilayer_perceptron(x, weights, biases)

#define the cost function and optimizer
cost_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y, labels=y))
training_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost_function)

sess = tf.Session()
sess.run(init)

#calculate the cost and the accuracy for each epoch
mse_history = []
accuracy_history = []

for epoch in range(training_epochs):
    sess.run(training_step, feed_dict={x: train_x, y_: train_y})
    cost = sess.run(cost_function, feed_dict={x: train_x, y_: train_y})
    cost_history = np.append(cost_history, cost)
    correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    print("Accuracy: ",(sess.run(accuracy, feed_dict={x: test_x, y_: test_y})))
    pred_y = sess.run(y,feed_dict={x: test_x})
    mse = tf.reduce_mean(tf.square(pred_y - test_y))
    mse_ = sess.run(mse)
    mse_history.append(mse_)
    accuracy = (sess.run(accuracy, feed_dict={x: train_x, y_: train_y}))
    accuracy_history.append(accuracy)
    
    print('epoch : ',epoch, ' - ', cost, " - MSE: ",mse_, "- Train Accuracy: ",accuracy)
    
save_path = saver.save(sess, model_path)
print("Model saved in file: %s" % save_path)

#plot mse and accuracy graph
plt.plot(mse_history, 'r')
plt.show()
plt.plot(accuracy_history)

#print the final accuracy
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
print("Test Accuracy: ", (sess.run(accuracy, feed_dict={x: test_x, y_: test_y})))

#print the final mean square error
pred_y = sess.run(y, feed_dict={x:test_x})
mse = tf.reduce_mean(tf.square(pred_y - test_y))
print("MSE: %.4f" % sess.run(mse))
# Out:
# (208, 60)
# (166, 60)
# (166, 2)
# (42, 60)
# n_dim 60
# Accuracy:  0.47619
# epoch :  0  -  -6.85698e+09  - MSE:  13213367793.7 - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  1  -  -4.49017e+31  - MSE:  8.64226305448e+31 - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  2  -  nan  - MSE:  inf - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  3  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  4  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  5  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  6  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  7  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  8  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  9  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  10  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  11  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  12  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  13  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  14  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  15  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  16  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  17  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  18  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  19  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  20  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  21  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  22  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  23  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  24  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  25  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  26  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  27  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  28  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  29  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  30  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  31  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  32  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  33  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  34  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  35  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  36  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  37  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  38  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  39  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  40  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  41  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  42  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  43  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  44  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  45  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  46  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  47  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  48  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  49  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  50  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  51  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  52  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  53  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  54  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  55  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  56  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  57  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  58  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  59  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  60  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  61  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  62  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  63  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  64  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  65  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  66  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  67  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  68  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  69  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  70  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  71  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  72  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  73  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  74  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  75  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  76  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  77  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  78  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  79  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  80  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  81  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  82  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  83  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  84  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  85  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  86  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  87  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  88  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  89  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  90  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  91  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  92  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  93  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  94  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  95  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  96  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  97  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  98  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  99  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  100  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  101  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  102  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  103  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  104  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  105  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  106  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  107  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  108  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  109  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  110  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  111  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  112  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  113  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  114  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  115  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  116  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  117  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  118  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  119  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  120  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  121  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  122  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  123  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  124  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  125  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  126  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  127  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  128  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  129  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  130  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  131  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  132  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  133  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  134  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  135  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  136  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  137  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  138  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  139  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  140  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  141  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  142  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  143  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  144  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  145  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  146  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  147  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  148  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  149  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  150  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  151  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  152  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  153  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  154  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  155  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  156  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  157  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  158  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  159  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  160  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  161  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  162  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  163  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  164  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  165  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  166  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  167  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  168  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  169  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  170  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  171  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  172  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  173  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  174  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  175  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  176  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  177  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  178  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  179  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  180  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  181  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  182  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  183  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  184  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  185  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  186  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  187  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  188  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  189  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  190  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  191  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  192  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  193  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  194  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  195  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  196  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  197  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  198  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  199  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  200  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  201  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  202  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  203  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  204  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  205  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  206  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  207  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  208  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  209  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  210  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  211  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  212  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  213  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  214  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  215  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  216  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  217  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  218  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  219  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  220  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  221  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  222  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  223  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  224  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  225  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  226  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  227  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  228  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  229  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  230  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  231  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  232  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  233  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  234  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  235  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  236  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  237  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  238  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  239  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  240  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  241  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  242  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  243  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  244  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  245  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  246  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  247  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  248  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  249  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  250  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  251  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  252  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  253  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  254  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  255  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  256  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  257  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  258  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  259  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  260  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  261  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  262  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  263  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  264  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  265  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  266  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  267  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  268  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  269  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  270  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  271  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  272  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  273  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  274  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  275  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  276  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  277  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  278  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  279  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  280  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  281  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  282  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  283  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  284  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  285  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  286  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  287  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  288  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  289  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  290  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  291  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  292  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  293  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  294  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  295  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  296  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  297  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  298  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  299  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  300  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  301  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  302  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  303  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  304  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  305  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  306  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  307  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  308  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  309  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  310  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  311  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  312  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  313  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  314  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  315  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  316  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  317  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  318  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  319  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  320  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  321  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  322  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  323  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  324  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  325  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  326  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  327  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  328  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  329  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  330  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  331  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  332  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  333  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  334  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  335  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  336  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  337  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  338  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  339  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  340  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  341  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  342  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  343  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  344  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  345  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  346  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  347  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  348  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  349  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  350  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  351  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  352  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  353  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  354  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  355  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  356  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  357  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  358  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  359  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  360  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  361  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  362  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  363  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  364  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  365  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  366  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  367  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  368  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  369  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  370  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  371  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  372  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  373  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  374  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  375  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  376  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  377  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  378  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  379  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  380  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  381  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  382  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  383  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  384  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  385  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  386  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  387  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  388  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  389  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  390  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  391  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  392  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  393  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  394  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  395  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  396  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  397  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  398  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  399  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  400  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  401  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  402  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  403  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  404  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  405  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  406  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  407  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  408  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  409  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  410  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  411  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  412  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  413  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  414  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  415  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  416  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  417  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  418  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  419  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  420  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  421  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  422  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  423  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  424  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  425  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  426  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  427  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  428  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  429  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  430  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  431  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  432  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  433  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  434  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  435  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  436  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  437  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  438  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  439  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  440  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  441  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  442  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  443  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  444  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  445  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  446  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  447  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  448  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  449  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  450  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  451  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  452  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  453  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  454  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  455  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  456  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  457  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  458  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  459  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  460  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  461  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  462  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  463  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  464  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  465  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  466  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  467  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  468  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  469  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  470  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  471  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  472  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  473  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  474  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  475  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  476  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  477  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  478  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  479  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  480  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  481  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  482  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  483  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  484  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  485  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  486  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  487  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  488  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  489  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  490  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  491  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  492  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  493  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  494  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  495  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  496  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  497  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  498  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  499  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  500  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  501  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  502  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  503  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  504  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  505  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  506  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  507  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  508  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  509  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  510  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  511  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  512  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  513  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  514  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  515  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  516  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  517  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  518  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  519  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  520  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  521  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  522  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  523  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  524  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  525  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  526  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  527  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  528  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  529  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  530  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  531  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  532  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  533  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  534  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  535  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  536  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  537  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  538  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  539  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  540  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  541  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  542  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  543  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  544  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  545  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  546  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  547  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  548  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  549  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  550  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  551  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  552  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  553  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  554  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  555  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  556  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  557  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  558  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  559  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  560  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  561  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  562  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  563  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  564  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  565  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  566  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  567  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  568  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  569  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  570  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  571  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  572  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  573  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  574  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  575  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  576  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  577  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  578  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  579  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  580  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  581  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  582  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  583  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  584  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  585  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  586  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  587  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  588  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  589  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  590  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  591  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# ...
# Accuracy:  0.47619
# epoch :  618  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  619  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  620  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  621  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  622  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  623  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  624  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  625  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  626  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  627  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  628  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  629  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  630  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  631  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  632  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  633  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  634  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  635  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  636  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  637  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  638  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  639  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  640  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  641  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  642  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  643  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  644  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  645  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  646  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  647  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  648  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  649  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  650  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  651  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  652  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  653  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  654  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  655  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  656  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  657  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  658  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  659  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  660  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  661  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  662  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  663  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  664  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  665  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  666  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  667  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  668  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  669  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  670  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  671  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  672  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  673  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  674  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  675  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  676  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  677  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  678  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  679  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  680  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  681  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  682  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  683  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  684  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  685  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  686  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  687  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  688  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  689  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  690  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  691  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  692  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  693  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  694  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  695  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  696  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  697  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  698  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  699  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  700  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  701  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  702  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  703  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  704  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  705  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  706  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  707  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  708  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  709  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  710  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  711  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  712  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  713  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  714  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  715  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  716  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  717  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  718  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  719  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  720  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  721  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  722  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  723  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  724  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  725  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  726  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  727  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  728  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  729  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  730  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  731  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  732  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  733  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  734  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  735  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  736  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  737  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  738  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  739  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  740  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  741  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  742  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  743  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  744  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  745  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  746  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  747  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  748  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  749  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  750  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  751  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  752  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  753  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  754  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  755  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  756  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  757  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  758  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  759  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  760  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  761  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  762  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  763  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  764  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  765  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  766  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  767  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  768  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  769  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  770  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  771  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  772  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  773  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  774  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  775  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  776  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  777  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  778  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  779  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  780  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  781  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  782  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  783  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  784  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  785  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  786  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  787  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  788  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  789  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  790  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  791  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  792  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  793  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  794  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  795  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  796  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  797  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  798  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  799  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  800  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  801  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  802  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  803  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  804  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  805  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  806  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  807  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  808  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  809  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  810  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  811  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  812  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  813  -  nan  - MSE:  nan - Train Accuracy:  0.548193
# Accuracy:  0.47619
# epoch :  814  -  nan  - MSE:  nan - Train Accuracy:  0.548193
